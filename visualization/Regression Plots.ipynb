# %%
import numpy as np
import pandas as pd

from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
 sns.lmplot("total_bill","tip",tips)

# %%
sns.lmplot("total_bill","tip",tips,hue = "sex")

# %%
sns.lmplot("total_bill","tip",tips,hue = "smoker")

# %%
sns.lmplot("total_bill","tip",tips,markers = ["x"])

# %%
sns.lmplot("total_bill","tip",hue = "smoker",data = tips,markers=["x","o"])

# %%
sns.lmplot("total_bill","tip",hue = "smoker",data = tips,markers=["x","o"] , palette = "Set1")

# %%
sns.lmplot("total_bill","tip",hue = "smoker",data = tips,palette = dict(Yes="r",No="g"))

# %%
sns.lmplot("total_bill","tip",tips,col="smoker")

# %%
sns.lmplot("total_bill","tip",tips,col = "day")

# %%
sns.lmplot("total_bill","tip",data = tips,hue = "day",col= "time")

# %%
sns.lmplot("total_bill","tip",data = tips,col = "time" , row = "sex")

# %%
sns.lmplot("total_bill","tip",data = tips
          ,line_kws = {"linewidth" : 1,"color":"indianred"})

# %%
sns.lmplot("total_bill","tip",data = tips , order =2)

# %%
sns.lmplot("total_bill","tip",data = tips , order =3)

# %%
sns.lmplot("total_bill","tip",data = tips ,fit_reg= False)

# %%
tips["tip_perc"] = 100*(tips["tip"]/tips["total_bill"])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_perc
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.lmplot("size","tip_perc",tips)

# %%
sns.lmplot("size","tip_perc",tips , x_jitter= 0.1)

# %%
sns.lmplot("size","tip_perc",data = tips ,x_estimator=np.mean)

# %%
sns.lmplot("total_bill","tip_perc",tips,hue = "sex" )

# %%
sns.lmplot("total_bill","tip_perc",tips)

# %%
sns.regplot("total_bill","tip_perc",tips)
## Lower level method i.e. More Robust

# %%
sns.regplot("total_bill","tip_perc",tips)
sns.factorplot("size",data = tips,kind = "count")
