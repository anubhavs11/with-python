# %%
import pandas as pd

# %%
df = pd.read_csv("input/employees.csv")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %% [markdown]
# ## Memory optimization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.Gender.nunique()
# Out:
# 2

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])

# String can also be converted to datetime when loading the dataset as:

# df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df.Team.nunique()
# Out:
# 10

# %%
df.Team.count()
# Out:
# 957

# %%
df["Team"] = df["Team"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-06-20 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
(62.6-42.6)/62.6*100
# 31.94% memory optimization
# Out:
# 31.948881789137378

# %% [markdown]
# ### Filter a dataFrame based on a condition

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
(df["Gender"] == "Male").head(3)
# return True instead of "Male" and false instead of "Female"
# Out:
# 0     True
# 1     True
# 2    False
# Name: Gender, dtype: bool

# %%
df[df["Gender"] == "Male"].head(3)
# returns data of only Males
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
df[df["Gender"] != "Male"].head(3)
# returns data of only Females
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
# 6       Ruby  Female 1987-08-17 2018-06-20 16:20:00   65476   10.012
# 7        NaN  Female 2015-07-20 2018-06-20 10:43:00   45906   11.598
#
#    Senior Management     Team
# 2              False  Finance
# 6               True  Product
# 7               True  Finance

# %%
mask = df["Team"] == "Finance"
df[mask].head(3)
# returns data of employee from the finance team only
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
# 7        NaN  Female 2015-07-20 2018-06-20 10:43:00   45906   11.598
#
#    Senior Management     Team
# 2              False  Finance
# 3               True  Finance
# 7               True  Finance

# %%
df["Senior Management"].head(3)
# Out:
# 0     True
# 1     True
# 2    False
# Name: Senior Management, dtype: bool

# %%
mask = df["Senior Management"] #contains only boolean values
df[mask].head(3)
# returns data of employee which are in Senior Management
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
df["Salary"] >= 1000000
df[mask].head(3)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
mask = df["Bonus %"] < 1.5
df[mask].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4       Larry    Male 1998-01-24 2018-06-20 16:47:00  101004    1.389
# 15    Lillian  Female 2016-06-05 2018-06-20 06:09:00   59414    1.256
# 58    Theresa  Female 2010-04-11 2018-06-20 07:18:00   72670    1.481
#
#     Senior Management             Team
# 4                True  Client Services
# 15              False          Product
# 58               True      Engineering

# %%
df["Last Login Time"].head(3)
# Out:
# 0   2018-06-20 12:42:00
# 1   2018-06-20 06:53:00
# 2   2018-06-20 11:17:00
# Name: Last Login Time, dtype: datetime64[ns]

# %%
mask = df["Start Date"] >= "2010-01-01"
df[mask].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 7         NaN  Female 2015-07-20 2018-06-20 10:43:00   45906   11.598
# 15    Lillian  Female 2016-06-05 2018-06-20 06:09:00   59414    1.256
# 16     Jeremy    Male 2010-09-21 2018-06-20 05:56:00   90370    7.369
#
#     Senior Management             Team
# 7                True          Finance
# 15              False          Product
# 16              False  Human Resources

# %% [markdown]
# ### Filter with more than one condition (AND)

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[ mask1 & mask2].head(3)
# returns male employees from marketing team
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 21    Matthew   Male 1995-09-05 2018-06-20 02:12:00  100612   13.645
# 26      Craig   Male 2000-02-27 2018-06-20 07:45:00   37598    7.757
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing

# %% [markdown]
# ### Filter with more than one condition (OR)

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Team"] == "Marketing"
mask2 = df["Senior Management"]
df[mask1 | mask2].head(3)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
mask1 = df["Team"] == "Marketing"
mask2 = df["Senior Management"]
mask3 = df["First Name"] == "Jerry"
df[mask1 | (mask2 & mask3)].head(3)
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 3       Jerry   Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
# 21    Matthew   Male 1995-09-05 2018-06-20 02:12:00  100612   13.645
#
#     Senior Management       Team
# 0                True  Marketing
# 3                True    Finance
# 21              False  Marketing

# %% [markdown]
# ### The .isin() method

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Team"] == "Product"
mask2 = df["Team"] == "Engineering"
mask3 = df["Team"] == "Sales"
df[mask1 | mask2 |mask3].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 6        Ruby  Female 1987-08-17 2018-06-20 16:20:00   65476   10.012
# 8      Angela  Female 2005-11-22 2018-06-20 06:29:00   95570   18.523
# 13       Gary    Male 2008-01-27 2018-06-20 23:40:00  109831    5.831
#
#     Senior Management         Team
# 6                True      Product
# 8                True  Engineering
# 13              False        Sales

# %%
mask = df["Team"].isin(["Product","Engineering","Sales"])
df[mask].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 6        Ruby  Female 1987-08-17 2018-06-20 16:20:00   65476   10.012
# 8      Angela  Female 2005-11-22 2018-06-20 06:29:00   95570   18.523
# 13       Gary    Male 2008-01-27 2018-06-20 23:40:00  109831    5.831
#
#     Senior Management         Team
# 6                True      Product
# 8                True  Engineering
# 13              False        Sales

# %% [markdown]
# ### The .isnull() and .notnull() methods

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
mask = df["Team"].isnull()
df[mask].head(3)
# returns data where Team as null
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2018-06-20 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2018-06-20 16:19:00  125792    5.042
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN

# %%
mask = df["Team"].notnull()
df[mask].head(3)
# returns data where Team as not null
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 3               True    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
mask1 = df["Team"].notnull()
mask2 = df["Gender"].notnull()
mask3 = df["First Name"].notnull()
df[mask1 & mask2 & mask3].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 3               True    Finance

# %% [markdown]
# ### The .between() method

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
mask = df["Salary"].between(90000,100000)
df[mask].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 8      Angela  Female 2005-11-22 2018-06-20 06:29:00   95570   18.523
# 16     Jeremy    Male 2010-09-21 2018-06-20 05:56:00   90370    7.369
#
#     Senior Management             Team
# 0                True        Marketing
# 8                True      Engineering
# 16              False  Human Resources

# %%
mask = df["Bonus %"].between(2,5)
df[mask].head(3)
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas   Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 20       Lois    NaN 1995-04-22 2018-06-20 19:18:00   64714    4.934
# 40    Michael   Male 2008-10-10 2018-06-20 11:25:00   99283    2.665
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution

# %%
mask = df["Start Date"].between("2016-06-01","2018-06-20")
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2018-06-20 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2018-06-20 19:47:00  100705   16.961
# 451      Terry     NaN 2016-07-15 2018-06-20 00:29:00  140002   19.490
#
#      Senior Management       Team
# 15               False    Product
# 98                True  Marketing
# 451               True  Marketing

# %%
mask = df["Last Login Time"].between("12:00:00","12:03:00")
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 61      Denise  Female 2001-11-06 2018-06-20 12:03:00  106862    3.699
# 591     Rachel  Female 1988-04-22 2018-06-20 12:01:00  110924    7.808
# 847     Nicole     NaN 1981-05-02 2018-06-20 12:03:00   41449    4.707
#
#      Senior Management                  Team
# 61               False  Business Development
# 591              False          Distribution
# 847              False               Finance

# %% [markdown]
# ### The .duplicated() method (applied only on Series)

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.sort_values("First Name",inplace = True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-20 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-06-20 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-06-20 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
df["First Name"].duplicated().head(4) # by default keep = first
#treat first element from the list of duplicates as not duplicate
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# Name: First Name, dtype: bool

# %%
df["First Name"].duplicated(keep = "last").head(4)
#treat last element from the list of duplicates as not duplicate
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# Name: First Name, dtype: bool

# %%
mask = df["First Name"].duplicated(keep = False)
# treat all dupicate elements as duplicated
df[mask].head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-20 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-06-20 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-06-20 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
mask = ~df["First Name"].duplicated(keep = False)  # tilde(~) as negation operator
# only unique values as True
df[mask].head(3)
#data of employees occurred only one times
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-06-20 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-06-20 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-06-20 03:39:00   57783    9.129
#
#      Senior Management         Team
# 8                 True  Engineering
# 688               True        Legal
# 190              False      Finance

# %% [markdown]
# ### The .drop_duplicates() method (applied on  dataframe)

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df.sort_values("First Name",inplace = True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-20 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-06-20 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-06-20 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
#no record is deleted, because all columns are not same for any two record
# Out:
# 1000

# %%
df.drop_duplicates(subset = "First Name").head(3) # by default keep = first
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-20 10:20:00   61602   11.849
# 137       Adam   Male 2011-05-21 2018-06-20 01:45:00   95327   15.120
# 300       Alan   Male 1988-06-26 2018-06-20 03:54:00  111786    3.592
#
#      Senior Management          Team
# 101               True     Marketing
# 137              False  Distribution
# 300               True   Engineering

# %%
df.drop_duplicates(subset = "First Name",keep = "last").head(3) # keep last occurances of repeated values
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron    NaN 1986-01-22 2018-06-20 19:39:00   63126   18.424
# 538       Adam   Male 2010-10-08 2018-06-20 21:53:00   45181    3.491
# 610       Alan   Male 2012-02-17 2018-06-20 00:26:00   41453   10.084
#
#      Senior Management             Team
# 937              False  Client Services
# 538              False  Human Resources
# 610              False          Product

# %%
df.drop_duplicates(subset = "First Name",keep = False).head(3)
# returns values occured only once
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-06-20 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-06-20 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-06-20 03:39:00   57783    9.129
#
#      Senior Management         Team
# 8                 True  Engineering
# 688               True        Legal
# 190              False      Finance

# %%
df.drop_duplicates(subset = ["First Name","Team"]).head(3)
# returns data by removing records in which both collumns have same value in at least 2 records
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-20 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2018-06-20 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2018-06-20 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 137              False     Distribution

# %%
df.drop_duplicates(subset = ["First Name","Team","Gender"]).head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-20 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2018-06-20 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2018-06-20 19:39:00   63126   18.424
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 937              False  Client Services

# %% [markdown]
# ### The .unique() and .nunique() methods

# %%
df = pd.read_csv("input/employees.csv",parse_dates=["Start Date","Last Login Time"])
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-20 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"].unique()
# Out:
# [Male, Female, NaN]
# Categories (2, object): [Male, Female]

# %%
df["Team"].unique()
# Out:
# [Marketing, NaN, Finance, Client Services, Legal, ..., Engineering, Business Development, Human Resources, Sales, Distribution]
# Length: 11
# Categories (10, object): [Marketing, Finance, Client Services, Legal, ..., Business Development, Human Resources, Sales, Distribution]

# %%
len(df["Gender"].unique())
# Out:
# 3

# %%
df["Gender"].nunique() #by default dropna = True , means ignores null values to count
# Out:
# 2

# %%
df["Gender"].nunique(dropna = False)
# Out:
# 3
